# %%
import pandas as pd
d=pd.read_csv('/content/vignesh.csv')
print(d)
# Out:
#         Name Department  Marks
# 0    Vignesh        CSE     85
# 1  Chaitanya        ECE     95
# 2      Rohit       MECH     76
# 3      Vinay      CIVIL     88

# %%
d=pd.read_excel('/content/vignesh.xlsx')
print(d)
# Out:
#         Name Department  Marks
# 0    Vignesh        CSE     85
# 1  Chaitanya        ECE     95
# 2      Rohit       MECH     76
# 3      Vinay      CIVIL     88

# %%
d=pd.read_csv('/content/vignesh.tsv')
print(d)
# Out:
#   Name\tDepartment\tMarks
# 0        Vignesh\tCSE\t85
# 1      Chaitanya\tECE\t95
# 2         Rohit\tMECH\t76
# 3        Vinay\tCIVIL\t88
